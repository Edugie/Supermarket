# %% [markdown]
# # Covenlab project

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame, Series

# %%
file_path = "supermarket_sales - Sheet1.csv"

# %%
super_market = pd.read_csv(file_path)

# %% [markdown]
# # The most frequent customer type and per month
# # Payment method: most frequent
# # Gender type and the highest buyers
# # Highest selling City per month
# # City with the highest sales
# # Month with the highest sales

# %%
# Most frequent customer type and per month
# the aim is to visualize the most common customer type

# %%
super_market
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# 9    692-92-5582      B   Mandalay        Member  Female
# 10   351-62-0822      B   Mandalay        Member  Female
# 11   529-56-3974      B   Mandalay        Member    Male
# 12   365-64-0515      A     Yangon        Normal  Female
# 13   252-56-2699      A     Yangon        Normal    Male
# 14   829-34-3910      A     Yangon        Normal  Female
# ...

# %%
customer_type = super_market["Customer type"]

# %%
customer_type
# Out:
# 0      Member
# 1      Normal
# 2      Normal
# 3      Member
# 4      Normal
# 5      Normal
# 6      Member
# 7      Normal
# 8      Member
# 9      Member
# 10     Member
# 11     Member
# 12     Normal
# 13     Normal
# 14     Normal
# 15     Member
# 16     Member
# 17     Normal
# 18     Normal
# 19     Normal
# 20     Member
# 21     Normal
# 22     Normal
# 23     Normal
# 24     Member
# 25     Member
# 26     Normal
# 27     Normal
# 28     Normal
# 29     Normal
#         ...
# 970    Member
# 971    Member
# 972    Normal
# 973    Normal
# 974    Normal
# 975    Member
# 976    Normal
# 977    Member
# 978    Normal
# 979    Normal
# 980    Member
# 981    Normal
# 982    Member
# 983    Normal
# 984    Normal
# 985    Normal
# 986    Normal
# 987    Member
# 988    Member
# 989    Member
# 990    Normal
# 991    Normal
# 992    Normal
# 993    Normal
# 994    Member
# 995    Normal
# 996    Normal
# 997    Member
# 998    Normal
# 999    Member
# ...

# %%
x = customer_type.value_counts()

# %%
x
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
x.plot.bar()

# %%
customer_type_by_month = super_market[["Date", "Customer type"]]

# %%
group_by = customer_type_by_month.groupby("Date")

# %%
group_by

# %%
x = group_by.first()

# %%
x
# Out:
#           Customer type
# Date
# 1/1/2019         Normal
# 1/10/2019        Member
# 1/11/2019        Member
# 1/12/2019        Member
# 1/13/2019        Normal
# 1/14/2019        Normal
# 1/15/2019        Member
# 1/16/2019        Member
# 1/17/2019        Member
# 1/18/2019        Normal
# 1/19/2019        Member
# 1/2/2019         Normal
# 1/20/2019        Member
# 1/21/2019        Normal
# 1/22/2019        Normal
# 1/23/2019        Normal
# 1/24/2019        Normal
# 1/25/2019        Normal
# 1/26/2019        Normal
# 1/27/2019        Member
# 1/28/2019        Member
# 1/29/2019        Normal
# 1/3/2019         Normal
# 1/30/2019        Normal
# 1/31/2019        Normal
# 1/4/2019         Member
# 1/5/2019         Member
# 1/6/2019         Normal
# 1/7/2019         Member
# 1/8/2019         Normal
# ...                 ...
# 3/1/2019         Normal
# 3/10/2019        Normal
# 3/11/2019        Member
# 3/12/2019        Normal
# 3/13/2019        Member
# 3/14/2019        Normal
# ...

# %%
super_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
# Invoice ID                 1000 non-null object
# Branch                     1000 non-null object
# City                       1000 non-null object
# Customer type              1000 non-null object
# Gender                     1000 non-null object
# Product line               1000 non-null object
# Unit price                 1000 non-null float64
# Quantity                   1000 non-null int64
# Tax 5%                     1000 non-null float64
# Total                      1000 non-null float64
# Date                       1000 non-null object
# Time                       1000 non-null object
# Payment                    1000 non-null object
# cogs                       1000 non-null float64
# gross margin percentage    1000 non-null float64
# gross income               1000 non-null float64
# Rating                     1000 non-null float64
# ...

# %%
payment_method = super_market["Payment"]

# %%
payment_method
# Out:
# 0          Ewallet
# 1             Cash
# 2      Credit card
# 3          Ewallet
# 4          Ewallet
# 5          Ewallet
# 6          Ewallet
# 7          Ewallet
# 8      Credit card
# 9      Credit card
# 10         Ewallet
# 11            Cash
# 12         Ewallet
# 13         Ewallet
# 14            Cash
# 15            Cash
# 16     Credit card
# 17     Credit card
# 18     Credit card
# 19         Ewallet
# 20         Ewallet
# 21         Ewallet
# 22     Credit card
# 23         Ewallet
# 24         Ewallet
# 25     Credit card
# 26            Cash
# 27     Credit card
# 28            Cash
# 29            Cash
#           ...
# 970    Credit card
# 971        Ewallet
# 972           Cash
# 973           Cash
# 974           Cash
# 975    Credit card
# 976           Cash
# 977        Ewallet
# 978    Credit card
# 979    Credit card
# 980           Cash
# 981           Cash
# 982        Ewallet
# 983           Cash
# 984           Cash
# 985        Ewallet
# ...

# %%
y = payment_method.value_counts()

# %%
y
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
y.plot.bar();

# %%
activities = ["Ewallet", "Cash", "Credit card"]

# %%
plt.pie(y, labels = activities, startangle=90, shadow=True, explode=(0, 0, 0), autopct="%1.1f%%");

plt.legend();

# %%
gender_total_sales = super_market[["Gender", "Total"]]

# %%
gender_total_sales
# Out:
#      Gender      Total
# 0    Female   548.9715
# 1    Female    80.2200
# 2      Male   340.5255
# 3      Male   489.0480
# 4      Male   634.3785
# 5      Male   627.6165
# 6    Female   433.6920
# 7    Female   772.3800
# 8    Female    76.1460
# 9    Female   172.7460
# 10   Female    60.8160
# 11     Male   107.1420
# 12   Female   246.4875
# 13     Male   453.4950
# 14   Female   749.4900
# 15   Female   590.4360
# 16   Female   506.6355
# 17     Male   457.4430
# 18     Male   172.2105
# 19   Female    84.6300
# 20     Male   451.7100
# 21     Male   277.1370
# 22     Male    69.7200
# 23     Male   181.4400
# 24     Male   279.1845
# 25   Female   441.7560
# 26     Male    35.1960
# 27   Female   184.1070
# 28   Female   463.8900
# 29     Male   235.2105
# ..      ...        ...
# 970  Female   888.6150
# 971    Male   271.2885
# 972    Male   640.0380
# 973    Male   252.2520
# 974    Male   180.8730
# 975    Male   104.8320
# 976  Female   313.5720
# 977    Male   167.5800
# ...

# %%
group_by_gender = super_market.groupby("Gender")

# %%
for Male, Male_df in group_by_gender:
    print(Male)
    print(Male_df)
# Out:
# Female
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# 9    692-92-5582      B   Mandalay        Member  Female
# 10   351-62-0822      B   Mandalay        Member  Female
# 12   365-64-0515      A     Yangon        Normal  Female
# 14   829-34-3910      A     Yangon        Normal  Female
# 15   299-46-1805      B   Mandalay        Member  Female
# 16   656-95-9349      A     Yangon        Member  Female
# 19   319-50-3348      B   Mandalay        Normal  Female
# 25   227-03-5010      A     Yangon        Member  Female
# 27   189-17-4241      A     Yangon        Normal  Female
# 28   145-94-9061      B   Mandalay        Normal  Female
# ...

# %%
number = group_by_gender.get_group("Male")

# %%
total_male = number["Total"].sum()

# %%
female = group_by_gender.get_group("Female")

# %%
total_female = female["Total"].sum()

# %%
super_market
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# 5    699-14-3026      C  Naypyitaw        Normal    Male
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# 9    692-92-5582      B   Mandalay        Member  Female
# 10   351-62-0822      B   Mandalay        Member  Female
# 11   529-56-3974      B   Mandalay        Member    Male
# 12   365-64-0515      A     Yangon        Normal  Female
# 13   252-56-2699      A     Yangon        Normal    Male
# 14   829-34-3910      A     Yangon        Normal  Female
# ...

# %%
df1 = pd.Series(total_male)

# %%
df2 = pd.Series(total_female)

# %%
male = pd.DataFrame(df1, columns=["Male"])

# %%
male
# Out:
#          Male
# 0  155083.824

# %%
female = pd.DataFrame(df2, columns=["Female"])

# %%
female
# Out:
#        Female
# 0  167882.925

# %%
conc = pd.concat([male, female])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
conc
# Out:
#        Female        Male
# 0         NaN  155083.824
# 0  167882.925         NaN

# %%
y = conc.fillna(0)

# %%
x = number["Total"]

# %%
x.plot(kind="bar")

# %%
super_market[super_market["Gender"] == "Male"]["Total"].sum()
# Out:
# 155083.824

# %%
x = super_market["City"].value_counts()

# %%
x
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
acts = ["A", "B", "C" ]

# %%
plt.pie(x, labels = acts, startangle=90, shadow=True, explode=(0.2, 0.1, 0), autopct="%1.1f%%");

# %%
super_market[["Gender", "Total"]]
# Out:
#      Gender      Total
# 0    Female   548.9715
# 1    Female    80.2200
# 2      Male   340.5255
# 3      Male   489.0480
# 4      Male   634.3785
# 5      Male   627.6165
# 6    Female   433.6920
# 7    Female   772.3800
# 8    Female    76.1460
# 9    Female   172.7460
# 10   Female    60.8160
# 11     Male   107.1420
# 12   Female   246.4875
# 13     Male   453.4950
# 14   Female   749.4900
# 15   Female   590.4360
# 16   Female   506.6355
# 17     Male   457.4430
# 18     Male   172.2105
# 19   Female    84.6300
# 20     Male   451.7100
# 21     Male   277.1370
# 22     Male    69.7200
# 23     Male   181.4400
# 24     Male   279.1845
# 25   Female   441.7560
# 26     Male    35.1960
# 27   Female   184.1070
# 28   Female   463.8900
# 29     Male   235.2105
# ..      ...        ...
# 970  Female   888.6150
# 971    Male   271.2885
# 972    Male   640.0380
# 973    Male   252.2520
# 974    Male   180.8730
# 975    Male   104.8320
# 976  Female   313.5720
# 977    Male   167.5800
# ...

# %%
import numpy as np

# %%
import seaborn as sns

# %%
sns.barplot(x="Gender", y="Total", data=super_market, estimator=np.sum);

# %%
css.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-207-1c07b249b230> in <module>
# ----> 1 css.to_excel("testing.xlsx")
#
# AttributeError: 'AxesSubplot' object has no attribute 'to_excel'

# %%
super_market["Unit price"].suml()
# Out:
# 55672.130000000005

# %%
super_market[super_market["Gender"] == "Female"]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 6    355-53-5943      A     Yangon        Member  Female
# 7    315-22-5665      C  Naypyitaw        Normal  Female
# 8    665-32-9167      A     Yangon        Member  Female
# 9    692-92-5582      B   Mandalay        Member  Female
# 10   351-62-0822      B   Mandalay        Member  Female
# 12   365-64-0515      A     Yangon        Normal  Female
# 14   829-34-3910      A     Yangon        Normal  Female
# 15   299-46-1805      B   Mandalay        Member  Female
# 16   656-95-9349      A     Yangon        Member  Female
# 19   319-50-3348      B   Mandalay        Normal  Female
# 25   227-03-5010      A     Yangon        Member  Female
# 27   189-17-4241      A     Yangon        Normal  Female
# 28   145-94-9061      B   Mandalay        Normal  Female
# ...

# %%
super_market[super_market["Gender"] == "Male" ]["Total"].sum()
# Out:
# 155083.824

# %%
167882.925 - 155083.824
# Out:
# 12799.100999999995

# %%
month_datetime = pd.to_datetime(super_market["Date"], yearfirst=False)

# %%
month_datetime
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
# 5     2019-03-25
# 6     2019-02-25
# 7     2019-02-24
# 8     2019-01-10
# 9     2019-02-20
# 10    2019-02-06
# 11    2019-03-09
# 12    2019-02-12
# 13    2019-02-07
# 14    2019-03-29
# 15    2019-01-15
# 16    2019-03-11
# 17    2019-01-01
# 18    2019-01-21
# 19    2019-03-11
# 20    2019-02-25
# 21    2019-03-05
# 22    2019-03-15
# 23    2019-02-17
# 24    2019-03-02
# 25    2019-03-22
# 26    2019-02-08
# 27    2019-03-10
# 28    2019-01-25
# 29    2019-03-15
#          ...
# 970   2019-01-01
# 971   2019-02-10
# 972   2019-01-26
# 973   2019-02-11
# 974   2019-02-07
# 975   2019-03-06
# 976   2019-03-04
# 977   2019-02-26
# 978   2019-03-10
# 979   2019-02-04
# 980   2019-01-19
# 981   2019-01-23
# 982   2019-03-14
# 983   2019-01-23
# 984   2019-01-09
# 985   2019-02-07
# 986   2019-02-18
# 987   2019-01-03
# 988   2019-03-29
# 989   2019-01-28
# 990   2019-03-22
# ...

# %%
month_datetime.value_counts()
# Out:
# 2019-02-07    20
# 2019-02-15    19
# 2019-01-08    18
# 2019-03-02    18
# 2019-03-14    18
# 2019-01-23    17
# 2019-01-26    17
# 2019-01-25    17
# 2019-03-05    17
# 2019-01-19    16
# 2019-03-09    16
# 2019-02-25    16
# 2019-03-19    16
# 2019-03-20    15
# 2019-01-28    14
# 2019-02-03    14
# 2019-03-03    14
# 2019-01-31    14
# 2019-01-27    14
# 2019-02-27    14
# 2019-02-02    14
# 2019-02-06    13
# 2019-01-24    13
# 2019-01-14    13
# 2019-03-26    13
# 2019-02-17    13
# 2019-02-09    13
# 2019-01-15    13
# 2019-01-05    12
# 2019-03-12    12
#               ..
# 2019-01-18     9
# 2019-03-25     9
# 2019-03-07     9
# 2019-03-16     9
# 2019-01-10     9
# 2019-02-24     9
# 2019-02-19     9
# 2019-01-07     9
# 2019-01-30     9
# 2019-02-16     8
# 2019-02-23     8
# 2019-01-09     8
# 2019-03-29     8
# 2019-01-02     8
# 2019-02-12     8
# 2019-02-11     8
# 2019-01-21     8
# 2019-02-14     8
# 2019-01-11     8
# 2019-02-13     8
# 2019-01-03     8
# ...

# %%
help(pd.to_datetime)
# Out:
# Help on function to_datetime in module pandas.core.tools.datetimes:
#
# to_datetime(arg, errors='raise', dayfirst=False, yearfirst=False, utc=None, box=True, format=None, exact=True, unit=None, infer_datetime_format=False, origin='unix', cache=False)
#     Convert argument to datetime.
#
#     Parameters
#     ----------
#     arg : integer, float, string, datetime, list, tuple, 1-d array, Series
#
#         .. versionadded:: 0.18.1
#
#            or DataFrame/dict-like
#
#     errors : {'ignore', 'raise', 'coerce'}, default 'raise'
#
#         - If 'raise', then invalid parsing will raise an exception
#         - If 'coerce', then invalid parsing will be set as NaT
#         - If 'ignore', then invalid parsing will return the input
#     dayfirst : boolean, default False
#         Specify a date parse order if `arg` is str or its list-likes.
#         If True, parses dates with the day first, eg 10/11/12 is parsed as
#         2012-11-10.
# ...

# %%
date =
